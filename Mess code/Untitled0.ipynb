# %%
pip install numpy
import numpy as npf

# Your series of cash flows, starting with the initial investment and followed by the cash inflows
cash_flows = [-660000, 208000, 201216, 194214.91, 186989.79, 179533.46, 171838.53, 163897.37, 155702.08, 147244.55, 138516.37, 234508.90, 225213.18, 215620, 205719.84, 195502.88, 184958.97, 174077.66, 162848.14, 151259.28, 139299.58, 258207.17, 245469.80, 232324.83, 218759.23, 204759.52, 190311.83, 175401.80, 160014.66, 144135.13, 127747.46]

# Calculate the IRR
irr = npf.irr(cash_flows)

print(f"The estimated IRR for the given cash flows is: {irr*100:.2f}%")
# Out:
#   File "<ipython-input-2-afdcecaf844b>", line 1
#     pip install numpy
#         ^
# SyntaxError: invalid syntax
